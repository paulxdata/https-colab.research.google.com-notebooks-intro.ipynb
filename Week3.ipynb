# %% [markdown]
# <a href="https://colab.research.google.com/github/paulxdata/https-colab.research.google.com-notebooks-intro.ipynb/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to compute average
def compute_average(scores):
    return sum(scores) / len(scores)

# Function to check pass or fail
def check_pass_fail(average):
    if average >= 50:
        return "Pass"
    else:
        return "Fail"

# List of 5 students with their scores
students = {
    "Student1": [60, 70, 80],
    "Student2": [45, 50, 40],
    "Student3": [90, 85, 88],
    "Student4": [30, 35, 40],
    "Student5": [55, 65, 75]
}

# Apply functions and print results
for name, scores in students.items():
    avg = compute_average(scores)
    result = check_pass_fail(avg)
    print(f"{name} - Average: {avg:.2f} - {result}")
print("Paul Amarachukwu udeh")
print("202550749955HA")
# Out:
# Student1 - Average: 70.00 - Pass
# Student2 - Average: 45.00 - Fail
# Student3 - Average: 87.67 - Pass
# Student4 - Average: 35.00 - Fail
# Student5 - Average: 65.00 - Pass
# Paul Amarachukwu udeh
# 202550749955HA
